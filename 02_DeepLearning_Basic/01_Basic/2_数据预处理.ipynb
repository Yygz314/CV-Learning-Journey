# %% [markdown]
# ## 数据预处理

# %% [markdown]
# 创建一个人工数据集，并存储在csv文件

# %%
import os

os.makedirs(os.path.join('.','data'),exist_ok = True)
data_file = os.path.join('.','data','house_tiny.csv')
with open(data_file,'w') as f:
    f.write('NumRooms,Alley,Price\n')    #列名
    f.write('NA.Pave,127500\n')   #每行表示一个数据样本
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,14000\n')

# %% [markdown]
# 从创建的csv文件中加载原始数据集

# %%
# !pip install pandas
import pandas as pd

data = pd.read_csv(data_file)
print(data)
# Out:
#   NumRooms     Alley     Price
# 0  NA.Pave  127500.0       NaN
# 1        2       NaN  106000.0
# 2        4       NaN  178100.0
# 3      NaN       NaN   14000.0

# %% [markdown]
# 处理缺失数据。包括插值、删除。下面考虑插值

# %%
inputs,outputs = data.iloc[:,0:2],data.iloc[:,2]
inputs = inputs.fillna(inputs.mean(numeric_only=True))
print(inputs)
# Out:
#   NumRooms     Alley
# 0  NA.Pave  127500.0
# 1        2  127500.0
# 2        4  127500.0
# 3      NaN  127500.0

# %% [markdown]
# 对于inputs中的类别值或离散值，我们将"NaN"视为一个类别

# %%
inputs = pd.get_dummies(inputs,drop_first = True,dummy_na = True).astype(int)
print(inputs)
# Out:
#     Alley  NumRooms_2  NumRooms_4  NumRooms_NA.Pave  NumRooms_nan
# 0  127500           0           0                 1             0
# 1  127500           1           0                 0             0
# 2  127500           0           1                 0             0
# 3  127500           0           0                 0             1

# %% [markdown]
# 现在inputs和outputs中所有条目都是数值类型，它们可以转换为张量格式

# %%
import torch

x,y = torch.tensor(inputs.values),torch.tensor(outputs.values)
x,y
# Out:
# (tensor([[127500,      0,      0,      1,      0],
#          [127500,      1,      0,      0,      0],
#          [127500,      0,      1,      0,      0],
#          [127500,      0,      0,      0,      1]], dtype=torch.int32),
#  tensor([    nan, 106000., 178100.,  14000.], dtype=torch.float64))
